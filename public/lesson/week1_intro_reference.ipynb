# %% [markdown]
# # Week 1 Monday — reference (intro card)
#
# Filled-in **example** you can open beside your own notebook to compare structure. Write your own prompts and text in `week1_intro.ipynb` — you learn more by typing than by pasting.

# %%
name = input("Name? ")
thing = input("Something you like doing (one short phrase)? ")
reason = input("Why are you taking this course? ")

print()
print("----------")
print(f"Name: {name}")
print(f"Likes: {thing}")
print(f"Here because: {reason}")
print("Thursday is build day — bring this folder and we will extend it.")
print("----------")
print()
