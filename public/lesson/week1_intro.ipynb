# %% [markdown]
# # CodeMoldova — Week 1 Monday lab
#
# Work through this **Jupyter notebook** (`.ipynb`) in **Cursor** with the lesson page open in a browser tab. **Run code cells from top to bottom** the first time so names like `week` exist when later cells use them.
#
# - **Markdown cells** (like this one): explanations — run them to read, or just read.
# - **Code cells**: Python — click in the cell, then **Shift+Enter** (run and move down).

# %% [markdown]
# ## 0 · Install Cursor
#
# If you do not have Cursor yet, download and install it first:
#
# **Download Cursor:** https://cursor.com/download (pick Windows, macOS, or Linux).
#
# Open Cursor when the install finishes. You will use it as your editor and to run this notebook.

# %% [markdown]
# ## 1 · Folder + open this notebook
#
# 1. Make a folder for this week (for example `codemoldova-week1`).
# 2. On the lesson page, click **Download starter notebook (.ipynb)** and save **week1_intro.ipynb** **inside** that folder.
# 3. In Cursor: **File → Open Folder…** and choose that folder.
# 4. Open `week1_intro.ipynb` from the sidebar.
# 5. If Cursor asks you to pick a **Python interpreter** or **kernel**, choose **Python 3**.
#
# If a cell shows `[*]` for a long time on first run, the environment may still be setting up — ask a mentor.

# %% [markdown]
# ## 2 · Check Python from the notebook
# Run the next cell. You should see a short version line printed under the cell.

# %%
import sys
print("Python:", sys.version.split()[0])

# %% [markdown]
# ## 3 · Expressions
# Each **code cell** is like the `>>>` prompt in tutorials: Python reads your code and shows a result. The **terminal** (shell) is separate — you will use it in later weeks; today the notebook is home base.

# %%
2 + 2
7 * 8

# %% [markdown]
# ## 4 · Variables, `print()`, and f-strings
# A **variable** is a name for a value. `print()` sends text to the cell output. **f-strings** let you insert values with `{curly braces}`. Run the next cell.

# %%
week = 1
course = "CodeMoldova"
print(f"{course}, week {week}")

# %% [markdown]
# ## 5 · `input()` in a notebook
# When you run a cell that calls `input()`, a prompt appears **in the notebook UI** (often above the output) — type your answer and press **Enter**. If nothing appears, ask a mentor (setups differ slightly).

# %%
name = input("What is your name? ")
print(f"Hi, {name}")

# %% [markdown]
# ## 6 · Mini practice (you)
# In the **next** cell, add code that:
#
# 1. Calls `input()` **twice** (store the answers in two variables).
# 2. `print`s **one** f-string that uses **both** variables (for example city and favorite food).
#
# Run the cell when you are done.

# %%
# TODO: two input() calls + one print with an f-string using both.

# %% [markdown]
# ## 7 · Main build — intro card
# Ask for **three** pieces of text (examples: name, one hobby, why you are here). Print a short **card**: several lines, **at least one f-string**, and **one line that mentions Thursday** (weekly build day).
#
# Replace the placeholder in the next cell with your own program. Do not copy the reference notebook word for word — you learn more by typing.

# %%
# intro_card — your prompts and messages
# name = input("Name? ")
# ... two more input() calls ...
# several print() lines, at least one f-string, one line about Thursday
pass  # delete this line when you add real code
