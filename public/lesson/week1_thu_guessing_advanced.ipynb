# %% [markdown]
# # Week 1 Thursday — Number guessing (advanced starter)
#
# Open in **Cursor** with the lesson **Advanced** tab. Build in the next cell.
#
# On the site: task, pseudocode, hints, and **Go beyond** (play again, presets, full Easy/Medium/Hard menu). Answer key in **Resources** matches those ideas.

# %%
# Your game
pass
