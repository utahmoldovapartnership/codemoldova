# %% [markdown]
# # Week 1 Thursday — Number guessing (beginner starter)
#
# Open this notebook in **Cursor** with the lesson **Beginner** tab. Write your game in the next cell.
#
# On the site: **Your task**, **Pseudocode**, **What to focus on**, **If you get stuck**, and **Go beyond** (welcome, play again, guess cap, Easy/Medium/Hard range). Worked examples for all of that are in the **Resources** tab → answer key (.ipynb).

# %%
# Your game
pass
